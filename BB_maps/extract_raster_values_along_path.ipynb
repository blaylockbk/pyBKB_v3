# %% [markdown]
# **Brian Blaylock**
# **3 December 2018**
#
# # Raster Values along a shapefile path
# I am trying to extract the values from a forecast grid along the path of powerlines.

# %%
import shapely
import geopandas as gpd
import numpy
import matplotlib.pyplot as plt

# %%
lakes = gpd.read_file('./shapefiles/LakesNHDHighRes/LakesNHDHighRes.shp')

# %%
plt.figure(figsize=[15,15])
lakes.plot()

# %%
lakes.geometry.values
# Out:
# array([<shapely.geometry.polygon.Polygon object at 0x000001F4826E5978>,
#        <shapely.geometry.polygon.Polygon object at 0x000001F4826E5B70>,
#        <shapely.geometry.polygon.Polygon object at 0x000001F4826E5CF8>,
#        ...,
#        <shapely.geometry.polygon.Polygon object at 0x000001F490D7C470>,
#        <shapely.geometry.polygon.Polygon object at 0x000001F490D7C5F8>,
#        <shapely.geometry.polygon.Polygon object at 0x000001F490D7C780>],
#       dtype=object)
