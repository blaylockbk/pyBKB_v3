# %%
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

import sys
sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v3')
sys.path.append('B:\pyBKB_v3')
from BB_HRRR.HRRR_Pando import get_hrrr_variable, get_hrrr_latlon

# %%
validDATE = datetime(2018, 1,1)
fxx = range(0,19)
variable='TMP:2 m'

# %%
run_fxx = [(validDATE - timedelta(hours=f),f) for f in fxx]

# %%
run_fxx
# Out:
# [(datetime.datetime(2018, 1, 1, 0, 0), 0),
#  (datetime.datetime(2017, 12, 31, 23, 0), 1),
#  (datetime.datetime(2017, 12, 31, 22, 0), 2),
#  (datetime.datetime(2017, 12, 31, 21, 0), 3),
#  (datetime.datetime(2017, 12, 31, 20, 0), 4),
#  (datetime.datetime(2017, 12, 31, 19, 0), 5),
#  (datetime.datetime(2017, 12, 31, 18, 0), 6),
#  (datetime.datetime(2017, 12, 31, 17, 0), 7),
#  (datetime.datetime(2017, 12, 31, 16, 0), 8),
#  (datetime.datetime(2017, 12, 31, 15, 0), 9),
#  (datetime.datetime(2017, 12, 31, 14, 0), 10),
#  (datetime.datetime(2017, 12, 31, 13, 0), 11),
#  (datetime.datetime(2017, 12, 31, 12, 0), 12),
#  (datetime.datetime(2017, 12, 31, 11, 0), 13),
#  (datetime.datetime(2017, 12, 31, 10, 0), 14),
#  (datetime.datetime(2017, 12, 31, 9, 0), 15),
#  (datetime.datetime(2017, 12, 31, 8, 0), 16),
#  (datetime.datetime(2017, 12, 31, 7, 0), 17),
#  (datetime.datetime(2017, 12, 31, 6, 0), 18)]

# %%
H = np.array([get_hrrr_variable(z[0], variable, fxx=z[1],
                                    verbose=False
                                    )['value']
              for z in run_fxx])

# %%
variance = np.var(H, axis=0)
mean_var =

# %%
plt.pcolormesh(variance)
