# %% [markdown]
# **Brian Blaylock**
# **October 10, 2019**
#
# # HRRR Hovmoller
# Makes HRRR hovemoller plots like what was displayed on the [old webpage](http://home.chpc.utah.edu/~u0553130/Brian_Blaylock/hrrr_golf.html).
# The original script is located on [GitHub](https://github.com/blaylockbk/oper/blob/master/HRRR_golf/HRRR_hovmoller.py).

# %%
from datetime import datetime, timedelta
from hovmoller_func import plot_hov, print_options

# %%
print_options()
# Out:
# Set the variable number from this list
# --------------------------------------
# 0: 10 m MAX Wind Speed
# 1: Simulated Reflectivity
# 2: 2 m Temperature
# 3: 2 m Dew Point
# 4: 2 m Relative Humidity
# 5: 1 h Accumulated Precipitation
# 6: Total Accumulated Precipitation
# 7: Solar Radiation

# %%
var_number = 2

# %%
## Recent Date range
UTC_now = datetime.utcnow()
sDATE = datetime(UTC_now.year, UTC_now.month, UTC_now.day, UTC_now.hour)-timedelta(hours=6)
eDATE = datetime(UTC_now.year, UTC_now.month, UTC_now.day, UTC_now.hour)+timedelta(hours=18)

## Custom Date range
#sDATE = datetime(2019, 6, 1, 0)
#eDATE = datetime(2019, 6, 2, 0)

# %%
stations = ['WBB', 'KMRY']
plot_hov(sDATE, eDATE, var_number, stations)
# Out:
# Retrieving from MesoWest API: http://api.mesowest.net/v2/stations/metadata?&token=2562b729557f45f5958516081f06c9eb&stid=WBB,KMRY
#
# Requested 2 m Temperature
# ---------------------------------------
# LocDic Time Series F00: Finished multiprocessing in 0:00:02.234624 on 22 processors
# LocDic Time Series F01: Finished multiprocessing in 0:00:02.544995 on 22 processors
# LocDic Time Series F02: Finished multiprocessing in 0:00:02.280449 on 22 processors
# LocDic Time Series F03: Finished multiprocessing in 0:00:02.372959 on 22 processors
# LocDic Time Series F04: Finished multiprocessing in 0:00:02.400901 on 22 processors
# LocDic Time Series F05: Finished multiprocessing in 0:00:02.496679 on 22 processors
# LocDic Time Series F06: Finished multiprocessing in 0:00:02.360645 on 22 processors
# LocDic Time Series F07: Finished multiprocessing in 0:00:02.875575 on 22 processors
# LocDic Time Series F08: Finished multiprocessing in 0:00:02.569296 on 22 processors
# LocDic Time Series F09: Finished multiprocessing in 0:00:02.235559 on 22 processors
# LocDic Time Series F10: Finished multiprocessing in 0:00:02.096412 on 22 processors
# LocDic Time Series F11: Finished multiprocessing in 0:00:02.520390 on 22 processors
# LocDic Time Series F12: Finished multiprocessing in 0:00:02.409976 on 22 processors
# LocDic Time Series F13: Finished multiprocessing in 0:00:02.404674 on 22 processors
# LocDic Time Series F14: Finished multiprocessing in 0:00:02.311590 on 22 processors
# LocDic Time Series F15: Finished multiprocessing in 0:00:02.295504 on 22 processors
# LocDic Time Series F16: Finished multiprocessing in 0:00:02.318517 on 22 processors
# LocDic Time Series F17: Finished multiprocessing in 0:00:03.753720 on 22 processors
# LocDic Time Series F18: Finished multiprocessing in 0:00:03.972179 on 22 processors
