# %% [markdown]
# *Brian Blaylock*
# *September 12, 2018*
#
# # HRRR Lightning Threat
#
# The HRRR Lightning field `LTNG` is the _Hourly Max lightning threat 3 based on a combination of threats 1 and 2_. It represents the entire atmosphere, and has units flashes/km^2/5min.
#
# Threat 1 is _Hourly Max lightning threat 1 based on vertical flux of graupel at -15C_
# Threat 2 is _Hourly Max lightning threat 2 based on vertical integrated frozen hydrometeors_
#
# ([GRIB Table](https://rapidrefresh.noaa.gov/hrrr/GRIB2Table_hrrr_2d.txt))
#
# ---
#
# Since the value is an hourly max, there are no values at F00. Must use F01 or greater.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import multiprocessing

import sys
sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v3')

from BB_HRRR.HRRR_Pando import get_hrrr_variable
from BB_maps.my_basemap import draw_HRRR_map

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [15,15]
mpl.rcParams['figure.titlesize'] = 15
mpl.rcParams['figure.titleweight'] = 'bold'
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10
mpl.rcParams['axes.labelsize'] = 12
mpl.rcParams['axes.titlesize'] = 15
mpl.rcParams['lines.linewidth'] = 1.8
mpl.rcParams['grid.linewidth'] = .25
mpl.rcParams['figure.subplot.wspace'] = 0.05
mpl.rcParams['figure.subplot.hspace'] = 0.05
mpl.rcParams['legend.fontsize'] = 10
mpl.rcParams['legend.framealpha'] = .75
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['savefig.bbox'] = 'tight'
mpl.rcParams['savefig.dpi'] = 100

# %%
m = draw_HRRR_map()

# %%
validDATE = datetime(2018, 9, 12, 19)
fxx = 1

runDATE = validDATE - timedelta(hours=fxx)
H = get_hrrr_variable(runDATE, 'LTNG:entire', fxx=fxx) 

masked = H['value']
masked = np.ma.array(masked)
masked[masked <= 0.02] = np.ma.masked
# Out:
#  >> Dowloading tempfile: ./temp_hrrr_2018091218_f01_LTN.grib2
# Oh, good, you requested a date that should be on Pando.
# GRIB2 File: https://pando-rgw01.chpc.utah.edu/hrrr/sfc/20180912/hrrr.t18z.wrfsfcf01.grib2
#  .idx File: https://pando-rgw01.chpc.utah.edu/hrrr/sfc/20180912/hrrr.t18z.wrfsfcf01.grib2.idx
#  >> Matched a variable:  54:31227984:d=2018091218:LTNG:entire atmosphere:1 hour fcst:
#  >> Byte Range: 31227984 31267233

# %%
plt.figure(figsize=[15,15])
m.pcolormesh(H['lon'], H['lat'], masked, cmap='plasma', latlon=True)
cb = plt.colorbar(orientation='horizontal', pad=.01, shrink=.8)
cb.set_label(r'Maximum Flashes km$\mathregular{^{-2}}$ 5min$\mathregular{^{-1}}$')

m.drawcoastlines()
m.drawcountries()
m.drawstates()


plt.title('HRRR Lightning Threat 3', fontweight='semibold');
plt.title('Run: %s F%02d' % (H['anlys'].strftime('%d %b %Y %H:%M UTC'), fxx), loc='left');
plt.title('Valid: %s' % H['valid'].strftime('%d %b %Y %H:%M UTC'), loc='right');

# %% [markdown]
# Accumulated Lightning Threat

# %%
def get_HRRR_lightning(DATE, fxx=1):
    H = get_hrrr_variable(DATE, 'LTNG:entire', fxx=fxx, value_only=True, verbose=False)
    return H['value']

# %%
def accumulate_grids(inputs):
    start = inputs[0]
    end = inputs[1]
    print(DATES[start], DATES[end])
    accum_chunk = np.sum([get_HRRR_lightning(D) for D in DATES[start:end]], axis=0)
    return accum_chunk

# %%
sDATE = datetime(2018, 5, 8)
eDATE = datetime(2018, 9, 7)
hours = (eDATE-sDATE).days*24 + int((eDATE-sDATE).seconds/60/60)
DATES = [sDATE + timedelta(hours=x) for x in range(hours)]

# %%
cpus = multiprocessing.cpu_count()
chunk_step = int(len(DATES)/cpus)
chunks = list(range(0, len(DATES), chunk_step)) + [-1]

# %%
chunk_sections = [(chunks[i], chunks[i+1]) for i in range(len(chunks)-1)]
print(len(chunk_sections))
print(chunk_sections)
# Out:
# 24
# [(0, 122), (122, 244), (244, 366), (366, 488), (488, 610), (610, 732), (732, 854), (854, 976), (976, 1098), (1098, 1220), (1220, 1342), (1342, 1464), (1464, 1586), (1586, 1708), (1708, 1830), (1830, 1952), (1952, 2074), (2074, 2196), (2196, 2318), (2318, 2440), (2440, 2562), (2562, 2684), (2684, 2806), (2806, -1)]

# %%
results = multiprocessing.Pool(cpus).map(accumulate_grids, chunk_sections)
# Out:
# 2018-06-12 14:00:00 2018-06-17 16:00:00
# 2018-05-08 00:00:00 2018-05-13 02:00:00
# 2018-05-18 04:00:00 2018-05-23 06:00:00
# 2018-06-27 20:00:00 2018-07-02 22:00:00
# 2018-06-17 16:00:00 2018-06-22 18:00:00
# 2018-06-02 10:00:00 2018-06-07 12:00:00
# 2018-07-02 22:00:00 2018-07-08 00:00:00
# 2018-05-23 06:00:00 2018-05-28 08:00:00
# 2018-06-22 18:00:00 2018-06-27 20:00:00
# 2018-06-07 12:00:00 2018-06-12 14:00:00
# 2018-05-28 08:00:00 2018-06-02 10:00:00
# 2018-05-13 02:00:00 2018-05-18 04:00:00
# 2018-07-13 02:00:00 2018-07-18 04:00:00
# 2018-07-08 00:00:00 2018-07-13 02:00:00
# 2018-08-17 16:00:00 2018-08-22 18:00:00
# 2018-09-01 22:00:00 2018-09-06 23:00:00
# 2018-08-07 12:00:00 2018-08-12 14:00:00
# 2018-07-23 06:00:00 2018-07-28 08:00:00
# 2018-08-02 10:00:00 2018-08-07 12:00:00
# 2018-07-18 04:00:00 2018-07-23 06:00:00
# 2018-08-22 18:00:00 2018-08-27 20:00:00
# 2018-08-12 14:00:00 2018-08-17 16:00:00
# 2018-08-27 20:00:00 2018-09-01 22:00:00
# 2018-07-28 08:00:00 2018-08-02 10:00:00

# %%
accum_lightning = np.sum(results, axis=0)

# %%
'''
use_multiprocessing = True

if use_multiprocessing:
    timer = datetime.now()
    cpus = multiprocessing.cpu_count()
    P = multiprocessing.Pool(cpus)
    
    # Due to memory errors, break up the input sequence into chuncks
    chunk_step = int(len(DATES)/cpus*2)
    chunks = list(range(0, len(DATES), chunk_step))
    
    accum_lightning = np.zeros_like(H['lat'])
    for i, chunk in enumerate(chunks):
        print(chunk/len(DATES)*100, '%')
        try:
            accum_lightning_chunk = np.sum(P.map(get_HRRR_lightning, DATES[chunks[i], chunks[i+1]]), axis=0)
        except:
            accum_lightning_chunk = np.sum(P.map(get_HRRR_lightning, DATES[chunks[i]:]), axis=0)
        accum_lightning += accum_lightning_chunk                                                                     
    
    print(datetime.now()-timer)
else:    
    accum_lightning = np.sum([get_HRRR_lightning(D) for D in DATES], axis=0)
'''
# Out:
# "\nuse_multiprocessing = True\n\nif use_multiprocessing:\n    timer = datetime.now()\n    cpus = multiprocessing.cpu_count()\n    P = multiprocessing.Pool(cpus)\n    \n    # Due to memory errors, break up the input sequence into chuncks\n    chunk_step = int(len(DATES)/cpus*2)\n    chunks = list(range(0, len(DATES), chunk_step))\n    \n    accum_lightning = np.zeros_like(H['lat'])\n    for i, chunk in enumerate(chunks):\n        print(chunk/len(DATES)*100, '%')\n        try:\n            accum_lightning_chunk = np.sum(P.map(get_HRRR_lightning, DATES[chunks[i], chunks[i+1]]), axis=0)\n        except:\n            accum_lightning_chunk = np.sum(P.map(get_HRRR_lightning, DATES[chunks[i]:]), axis=0)\n        accum_lightning += accum_lightning_chunk                                                                     \n    \n    print(datetime.now()-timer)\nelse:    \n    accum_lightning = np.sum([get_HRRR_lightning(D) for D in DATES], axis=0)\n"

# %%
len(DATES)
# Out:
# 2928

# %%
maskedA = accum_lightning
maskedA = np.ma.array(maskedA)
maskedA[maskedA <= 0.02] = np.ma.masked

# %%
m.pcolormesh(H['lon'], H['lat'], accum_lightning, cmap='magma', latlon=True, vmax=75)
cb = plt.colorbar(orientation='horizontal', pad=.01, shrink=.8)
cb.set_label(r'Maximum Flashes km$\mathregular{^{-2}}$ 5min$\mathregular{^{-1}}$')

m.drawcoastlines(color='grey')
m.drawcountries(color='grey')
m.drawstates(color='grey')


plt.title('Accumulated HRRR F%02d Lightning Threat 3' % fxx, loc='left', fontweight='semibold');
plt.title('Start: %s\n End: %s' % (sDATE.strftime('%d %b %Y'), eDATE.strftime('%d %b %Y')), loc='right', fontsize=10);

plt.savefig('figs/HRRR_F%02d_accumulated_lightning_threat' % fxx)
